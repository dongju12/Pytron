# %% [markdown]
# # 데이터 시각화

# %% [markdown]
# ![image.png](attachment:image.png)
# ![image-2.png](attachment:image-2.png)
# ![image-3.png](attachment:image-3.png)

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
# 배열 생성하여 데이터 준비
x = np.arange(1,6)
np.random.seed(3)
y = np.random.randint(1,10,size=5)
print(x)
print(y)
# Out:
# [1 2 3 4 5]
# [9 4 9 9 1]

# %%
# 선 그래프 그리기
# plt.plot(x축, y축)
plt.plot(x,y)

# 쥬피터 노트북, colab 환경에서는 plot을 그릴 때 별도의 코드 없이 그래프가 출력
# vacode, pytorch 등 plt.show()까지 작성
plt.show()

# %%
# 선 그리는 경우 x축 생략 가능
plt.plot(y)

# %% [markdown]
# # 선 그래프의 옵션
# ![image.png](attachment:image.png)
# ![image-2.png](attachment:image-2.png)
# ![image-3.png](attachment:image-3.png)

# %%
# 선 그래프 스타일 변경
# marker - 포인트에 스타일 변경
# ms(marker size)
# mec(marker edge color)
# mew(marker edge width)
# mfc(marker face color)
plt.plot(x,y,ls = ':', marker = 'p', ms = 10 , mec = 'b', c = 'y', mew = 2, mfc = 'g')
plt.show()

# %%
# 하나의 출력문의 여러개 그래프 그리기
plt.plot(x,y, ls = '-', color='b' ,marker='D', ms=10, mec='c',mew=4, mfc='y')
plt.plot(x,y, ls = '--', color='m', lw=5)
plt.plot(x,y, ls = '-.')
plt.plot(x,y, ls = ':')

plt.show()
# 별도의 코드가 없으면 겹쳐서 출력

# %%
### plt.subplot(row, col, index)

# %%
# 하나의 출력문의 여러개 그래프 그리기
# plt.subplot()

plt.subplot(3,2,1)
plt.plot(x,y, ls = '-', color='b' ,marker='D', ms=10, mec='c',mew=4, mfc='y')

plt.subplot(3,2,2)
plt.plot(x,y, ls = '--', color='m', lw=5)

plt.subplot(3,2,3)
plt.plot(x,y, ls = '-.')

plt.subplot(3,2,4)
plt.plot(x,y, ls = ':')

plt.subplot(3,2,5)
plt.plot(x,y, ls = ':')

plt.subplot(3,2,6)
plt.plot(x,y, ls = ':')

plt.show()
# 별도의 코드가 없으면 겹쳐서 출력

# %%
# 배열 생성하여 데이터 준비
test_x = np.arange(1,6)
np.random.seed(4)
test_y = np.random.randint(1,10,size=5)

plt.plot(test_x,test_y)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
# 그래프 제목 - title
plt.title("Hello World")
plt.plot(test_x,test_y)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
# 격자 눈금 - grid
plt.grid()
plt.title("test")
plt.plot(test_x,test_y)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
# 범례 - legend
test_x1 = np.arange(1,6)
np.random.seed(10)
test_y1 = np.random.randint(1,10,size=5)

plt.legend() # 아무런 코드 작성 없이 사용하게 되면 안나옵니다

plt.plot(test_x,test_y)
plt.plot(test_x1,test_y1)
plt.show
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
# 범례 - legend
test_x1 = np.arange(1,6)
np.random.seed(10)
test_y1 = np.random.randint(1,10,size=5)

plt.plot(test_x,test_y, label = "test1")
plt.plot(test_x1,test_y1, label = "test2")

# plt.plot 다음에 코드 작성하기
plt.legend() # 등장하게 하고 싶으면 plt.plot하는 구간에 label을 작성

plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
#한글 폰트 깨질 경우
plt.rcParams['font.family'] = 'Malgun Gothic'

# %%
# xlabel, ylabel
plt.plot(test_x,test_y, label = "test1")
plt.plot(test_x1,test_y1, label = "test2")

plt.xlabel("x축")
plt.ylabel("y축", rotation = 360, loc = "top")
# rotation은 label의 회전, 숫자의 의미는 각도
# loc top, bottom center 중 하나

plt.show()

# %%
# xlim, ylim - limit의 약자
# xlim(n, n1)
plt.plot(test_x,test_y, label = "test1")
plt.plot(test_x1,test_y1, label = "test2")

plt.xlim(0,3)
plt.ylim(0,5)

plt.show()

# %%
# plt.figure(x, y) 단위 : 인치
plt.figure(figsize =(5,2))

plt.plot(test_x,test_y, label = "test1")
plt.plot(test_x1,test_y1, label = "test2")

plt.show()

# %%
# xticks, yticks - 눈금의 범위 조정

plt.plot(test_x,test_y, label = "test1")
plt.plot(test_x1,test_y1, label = "test2")

# list, 배열
plt.xticks([1,2,3,4,5,6,7])
plt.yticks([1,3,5,7,9])

plt.show()

# %% [markdown]
# # 인구변동 데이터

# %%
data = pd.read_csv('data/장래_인구변동_KOSIS.csv', encoding = 'euc-kr', index_col = '인구변동요인별')
data
# Out:
#            2020   2030   2040   2050   2060   2070
# 인구변동요인별
# 인구(천명)    51836  51199  50193  47359  42617  37656
# 출생아수(천명)    275    305    286    236    181    196
# 사망자수(천명)    308    408    527    680    741    702

# %% [markdown]
# ### 출생아수, 사망자수를 데이터 시각화

# %%
#  출생아 수 데이터 접근
data_y1 = data.iloc[1]

# 사망자수 데이터 접근
data_y2 = data.iloc[2]

# %%
# 컬럼명을 뽑아 x축으로 설정
data_x = data.columns

# %%
plt.plot(data_x, data_y1, marker = "*", ms = 10 ,label = "출생아수(천명)")
plt.plot(data_x, data_y2, marker = "d", ms = 8, label = "사망자수(천명)")

# title
plt.title("국가통계 요인별 장래 인구 동향")

# grid
plt.grid()

# legend - plot label 작성해주기
plt.legend()

# plt.show()

# plt.savefig(경로+파일명, dpi(인치당 도트)- 숫자가 높을수록 고해상도, bbox_inches = 'tight' -> 빈칸 최소화)
plt.savefig('./kosis 요인별 장래 인구 동향.png', dpi=600, bbox_inches ='tight')

# %%
tdata = pd.read_csv('data/기상데이터.csv.csv', encoding = 'euc-kr', skiprows=range(0,7))
tdata.head(2)
# Out:
#              날짜   지점  평균기온(℃)  최저기온(℃)  최고기온(℃)
# 0  \t2010-01-01  156     -3.6     -9.5      1.9
# 1  \t2010-01-02  156      1.6     -3.9      6.6

# %%
tdata.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5159 entries, 0 to 5158
# Data columns (total 5 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   날짜       5159 non-null   object
#  1   지점       5159 non-null   int64
#  2   평균기온(℃)  5159 non-null   float64
#  3   최저기온(℃)  5159 non-null   float64
#  4   최고기온(℃)  5159 non-null   float64
# dtypes: float64(3), int64(1), object(1)
# memory usage: 201.7+ KB

# %%
# 최저기온 시각화
t_y = tdata['최저기온(℃)']

# %%
# 마이너스 기호 사용 코드
plt.rcParams['axes.unicode_minus'] = False

# %%
# 마이너스 출력 코드

plt.plot(t_y)
plt.show()

# %%
# 데이터 정제의 필요성
# 데이터 파생변수 만들기

# 월일 이라는 파생변수
tdata['월일'] = tdata['날짜'].str[-5:]
tdata
# Out:
#                 날짜   지점  평균기온(℃)  최저기온(℃)  최고기온(℃)     월일
# 0     \t2010-01-01  156     -3.6     -9.5      1.9  01-01
# 1     \t2010-01-02  156      1.6     -3.9      6.6  01-02
# 2     \t2010-01-03  156      0.4     -1.8      3.5  01-03
# 3     \t2010-01-04  156      0.5     -1.8      5.7  01-04
# 4     \t2010-01-05  156     -3.0     -4.9      0.2  01-05
# ...            ...  ...      ...      ...      ...    ...
# 5154  \t2024-02-11  156      3.2     -1.2      9.1  02-11
# 5155  \t2024-02-12  156      5.8     -0.9     13.0  02-12
# 5156  \t2024-02-13  156     10.6      3.4     17.6  02-13
# 5157  \t2024-02-14  156     13.5     10.6     19.0  02-14
# 5158  \t2024-02-15  156      6.4      0.5     12.4  02-15
#
# [5159 rows x 6 columns]

# %%
# 본인 생일날짜 평균기온 연도별 그래프 시각화

# 1. 본인 생일날짜 불리언 인덱싱
tdata.query("월일 == '03-18'")
birthday_tdata = tdata.query("월일 == '03-18'")
birthday_tdata
# Out:
#                 날짜   지점  평균기온(℃)  최저기온(℃)  최고기온(℃)     월일
# 76    \t2010-03-18  156      3.2     -0.8      6.4  03-18
# 441   \t2011-03-18  156      7.1     -2.1     16.7  03-18
# 807   \t2012-03-18  156      6.1      1.5     10.3  03-18
# 1172  \t2013-03-18  156     10.3      8.0     13.9  03-18
# 1537  \t2014-03-18  156     12.6      7.6     18.0  03-18
# 1902  \t2015-03-18  156     12.0      9.9     14.9  03-18
# 2268  \t2016-03-18  156     12.0      9.7     14.4  03-18
# 2633  \t2017-03-18  156      9.9      4.1     17.7  03-18
# 2998  \t2018-03-18  156      9.8      3.6     15.4  03-18
# 3363  \t2019-03-18  156      8.7      1.5     14.9  03-18
# 3729  \t2020-03-18  156     12.5      6.0     20.6  03-18
# 4094  \t2021-03-18  156     11.7      4.8     21.0  03-18
# 4459  \t2022-03-18  156      8.5      7.3     10.8  03-18
# 4824  \t2023-03-18  156     10.3      6.1     16.4  03-18

# %%
# 2. x, y설정
y = birthday_tdata['평균기온(℃)']
x = range(2010,2024)

plt.plot(x,y)
plt.show()

# %% [markdown]
# # 히스토그램
# - 분포도 파악이 주목적

# %%
# 데이터의 빈도를 막대 그래프 형태로 표시한 것
# 주사위를 100번 던져서 나오는 수들의 분포를 히스토그램으로 그려보기
np.random.seed(3)
a = np.random.randint(1,7, size = 100)
np.unique(a, return_counts=True) 

# hist(데이터, bins = 가로의 구간 개수)
plt.hist(a, bins = 6)
plt.show()

# %%
a
# Out:
# array([3, 1, 2, 4, 1, 1, 1, 6, 6, 4, 3, 4, 2, 2, 3, 6, 1, 5, 5, 6, 1, 3,
#        2, 3, 3, 3, 5, 2, 4, 3, 6, 1, 2, 6, 3, 1, 4, 1, 4, 2, 4, 1, 6, 5,
#        2, 6, 5, 5, 1, 1, 2, 3, 5, 6, 1, 1, 6, 6, 2, 2, 2, 6, 6, 3, 4, 5,
#        5, 4, 4, 1, 1, 1, 1, 3, 3, 4, 1, 6, 6, 1, 6, 2, 5, 2, 5, 3, 3, 5,
#        5, 3, 1, 5, 1, 4, 3, 1, 5, 4, 2, 6])

# %%
# tdata 월 데이터 파생변수
tdata['월'] = tdata['월일'].str[:2]
tdata
# Out:
#                 날짜   지점  평균기온(℃)  최저기온(℃)  최고기온(℃)     월일   월
# 0     \t2010-01-01  156     -3.6     -9.5      1.9  01-01  01
# 1     \t2010-01-02  156      1.6     -3.9      6.6  01-02  01
# 2     \t2010-01-03  156      0.4     -1.8      3.5  01-03  01
# 3     \t2010-01-04  156      0.5     -1.8      5.7  01-04  01
# 4     \t2010-01-05  156     -3.0     -4.9      0.2  01-05  01
# ...            ...  ...      ...      ...      ...    ...  ..
# 5154  \t2024-02-11  156      3.2     -1.2      9.1  02-11  02
# 5155  \t2024-02-12  156      5.8     -0.9     13.0  02-12  02
# 5156  \t2024-02-13  156     10.6      3.4     17.6  02-13  02
# 5157  \t2024-02-14  156     13.5     10.6     19.0  02-14  02
# 5158  \t2024-02-15  156      6.4      0.5     12.4  02-15  02
#
# [5159 rows x 7 columns]

# %%
# 2010~2024 2월 데이터 최고기온을 히스토그램으로 시각화
# 1. 2010 ~ 2024 2월 데이터 접근 -> 불리언 인덱싱
m2 = tdata.query("월 == '02'")
m2
# Out:
#                 날짜   지점  평균기온(℃)  최저기온(℃)  최고기온(℃)     월일   월
# 31    \t2010-02-01  156      3.6      0.5      7.9  02-01  02
# 32    \t2010-02-02  156     -0.6     -3.9      2.8  02-02  02
# 33    \t2010-02-03  156     -3.3     -5.4      0.4  02-03  02
# 34    \t2010-02-04  156     -1.4     -5.8      4.1  02-04  02
# 35    \t2010-02-05  156     -0.7     -4.3      4.4  02-05  02
# ...            ...  ...      ...      ...      ...    ...  ..
# 5154  \t2024-02-11  156      3.2     -1.2      9.1  02-11  02
# 5155  \t2024-02-12  156      5.8     -0.9     13.0  02-12  02
# 5156  \t2024-02-13  156     10.6      3.4     17.6  02-13  02
# 5157  \t2024-02-14  156     13.5     10.6     19.0  02-14  02
# 5158  \t2024-02-15  156      6.4      0.5     12.4  02-15  02
#
# [410 rows x 7 columns]

# %%
hist_tdata = m2['최고기온(℃)']

# %%
plt.hist(hist_tdata, bins = 100)
plt.show()

# %%
# 히스토그램 꾸미기
# color - 색 바꾸기
# alpha - 투명도 값 지정 0~1사이 소수 작성

# label - 지정가능
plt.hist(hist_tdata, bins = 100, color = 'y', alpha = 0.5, label="최고기온")

# 히스토그램도 겹치기 가능
plt.hist(m2['최저기온(℃)'], bins = 100, color = 'b', alpha = 0.5, label="최저기온")

plt.legend()
plt.title("2월 최고/최저기온")
plt.grid()
plt.show()

# %% [markdown]
# # boxplot

# %%
# 1D 데이터 준비하여 박스 플롯 그려보기
np.random.seed(1)
tmp_data = np.random.randint(10,size = 10)
print(tmp_data)
tmp_data= np.append(tmp_data, 20)
print(tmp_data)
plt.boxplot(tmp_data, labels=['데이터명'])
plt.show()
# Out:
# [5 8 9 5 0 0 1 7 6 9]
# [ 5  8  9  5  0  0  1  7  6  9 20]

# %%
tmp_data
# Out:
# array([ 5,  8,  9,  5,  0,  0,  1,  7,  6,  9, 20])

# %% [markdown]
# ### 1. 박스의 의미
#  - 데이터의 사분위 범위를 나타내는 것
#  - 2사분위와 3사분위의 데이터 표시
# ### 2. 수염의 의미
#  - 1사분위와 4사분위의 데이터
# ### 3. 박스 내 선의 의미
#  - 중앙값
# ### 4. 점 -> 주로 점은 선 밖에 위치
#  - 이상치
#
# - 중앙값, 분위별 데이터 확인, 이상치 데이터 확인

# %%
m2["평균기온(℃)"]
# Out:
# 31       3.6
# 32      -0.6
# 33      -3.3
# 34      -1.4
# 35      -0.7
#         ...
# 5154     3.2
# 5155     5.8
# 5156    10.6
# 5157    13.5
# 5158     6.4
# Name: 평균기온(℃), Length: 410, dtype: float64

# %%
# plt.boxplot(데이터, labels = [])
plt.boxplot(m2["평균기온(℃)"], labels=['평균기온'])
plt.show()

# %%
m2[m2["평균기온(℃)"]< -5]
# Out:
#                 날짜   지점  평균기온(℃)  최저기온(℃)  최고기온(℃)     월일   월
# 762   \t2012-02-02  156     -7.9     -9.7     -5.2  02-02  02
# 768   \t2012-02-08  156     -5.7     -9.3     -2.0  02-08  02
# 1134  \t2013-02-08  156     -6.3     -9.7     -1.4  02-08  02
# 2956  \t2018-02-04  156     -5.9     -8.3     -3.0  02-04  02
# 2957  \t2018-02-05  156     -5.6     -8.5     -1.7  02-05  02
# 2958  \t2018-02-06  156     -6.5     -9.8     -2.8  02-06  02

# %% [markdown]
# # barplot

# %%
# 데이터 준비하여 막대 그래프 그려보기
np.random.seed(6)
bar_x = np.arange(1,4)
bar_y = np.random.randint(50,100,size=3)

# plt.bar(x, y)
plt.bar(bar_x,bar_y)
plt.show()

# %%
# barplot 꾸미기
# https://matplotlib.org/stable/gallery/color/named_colors.html#base-colors  doc제공 코드
import math
from matplotlib.patches import Rectangle
import matplotlib.pyplot as plt
import matplotlib.colors as mcolors


def plot_colortable(colors, *, ncols=4, sort_colors=True):

    cell_width = 212
    cell_height = 22
    swatch_width = 48
    margin = 12

    # Sort colors by hue, saturation, value and name.
    if sort_colors is True:
        names = sorted(
            colors, key=lambda c: tuple(mcolors.rgb_to_hsv(mcolors.to_rgb(c))))
    else:
        names = list(colors)

    n = len(names)
    nrows = math.ceil(n / ncols)

    width = cell_width * 4 + 2 * margin
    height = cell_height * nrows + 2 * margin
    dpi = 72

    fig, ax = plt.subplots(figsize=(width / dpi, height / dpi), dpi=dpi)
    fig.subplots_adjust(margin/width, margin/height,
                        (width-margin)/width, (height-margin)/height)
    ax.set_xlim(0, cell_width * 4)
    ax.set_ylim(cell_height * (nrows-0.5), -cell_height/2.)
    ax.yaxis.set_visible(False)
    ax.xaxis.set_visible(False)
    ax.set_axis_off()

    for i, name in enumerate(names):
        row = i % nrows
        col = i // nrows
        y = row * cell_height

        swatch_start_x = cell_width * col
        text_pos_x = cell_width * col + swatch_width + 7

        ax.text(text_pos_x, y, name, fontsize=14,
                horizontalalignment='left',
                verticalalignment='center')

        ax.add_patch(
            Rectangle(xy=(swatch_start_x, y-9), width=swatch_width,
                      height=18, facecolor=colors[name], edgecolor='0.7')
        )

    return fig

plot_colortable(mcolors.CSS4_COLORS)
plt.show()

# %%
# barplot 꾸미기
# color 지정
plt.bar(bar_x, bar_y, color = 'b')
plt.show()

# %%
# color 바 별로 별도 적용
# color = []
plt.bar(bar_x, bar_y, color = ['limegreen','mediumslateblue','orange'])
plt.show()

# %%
# bar에 데이터 값 작성
# plt.text()
plt.bar(bar_x, bar_y, color = ['limegreen','mediumslateblue','orange'])

# plt.text(x, y, 'str', fontdict = {'color' : '' , 'size' : 00 })
# plt.text(1, 60, '60', fontdict = {'color' : 'black' , 'size' : 15 })
# plt.text(2, 59, '59', fontdict = {'color' : 'black' , 'size' : 15 })
# plt.text(3, 85, '85', fontdict = {'color' : 'black' , 'size' : 15 })

# text(ha = , va =)
# ha = horizental alignment
# va = vertical alignment

# ha = center, right, left
# va = top, bottom, center, baseline, center_baseline

for i in range(len(bar_x)):
    plt.text(bar_x[i], bar_y[i], bar_y[i], fontdict = {'color' : 'black' , 'size' : 15 }, ha = 'right', va = 'bottom')
    
    
plt.show()

# %%
economic = pd.read_csv('data/시도_성별_경제활동인구_총괄_KOSIS_2022.csv', encoding = 'euc-kr')
economic.head()
# Out:
#   행정구역(시도)  성별  15세이상인구 (천명)  경제활동인구 (천명)  취업자 (천명)  실업자 (천명)  비경제활동인구 (천명)  \
# 0    서울특별시  남자          4007         2849      2760        89          1158
# 1    서울특별시  여자          4440         2418      2347        72          2022
# 2    부산광역시  남자          1406          973       946        27           433
# 3    부산광역시  여자          1528          768       745        23           760
# 4    대구광역시  남자          1001          708       691        17           294
#
#    경제활동참가율(％)  고용률(%)  실업률(%)
# 0        71.1    68.9     3.1
# 1        54.5     NaN     3.0
# 2        69.2    67.3     2.7
# 3        50.3    48.8     3.0
# 4        70.6    69.0     2.3

# %%
economic.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 34 entries, 0 to 33
# Data columns (total 10 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   행정구역(시도)      34 non-null     object
#  1   성별            34 non-null     object
#  2   15세이상인구 (천명)  34 non-null     int64
#  3   경제활동인구 (천명)   34 non-null     int64
#  4   취업자 (천명)      34 non-null     int64
#  5   실업자 (천명)      34 non-null     int64
#  6   비경제활동인구 (천명)  34 non-null     int64
#  7   경제활동참가율(％)    34 non-null     float64
#  8   고용률(%)        24 non-null     float64
#  9   실업률(%)        28 non-null     float64
# dtypes: float64(3), int64(5), object(2)
# memory usage: 2.8+ KB

# %%
economic['고용률(%)']
# Out:
# 0     68.9
# 1      NaN
# 2     67.3
# 3     48.8
# 4     69.0
# 5      NaN
# 6      NaN
# 7      NaN
# 8      NaN
# 9      NaN
# 10     NaN
# 11     NaN
# 12    71.3
# 13    48.2
# 14    75.9
# 15    52.5
# 16    75.0
# 17     NaN
# 18    69.7
# 19    58.2
# 20    75.2
# 21    56.4
# 22    76.0
# 23    57.8
# 24    70.4
# 25    56.4
# 26    75.0
# 27     NaN
# 28    73.3
# 29    55.0
# 30    70.7
# 31    52.0
# 32    77.6
# 33    66.9
# Name: 고용률(%), dtype: float64

# %%
# 고용률 = 취업자 / 15세이상 인구
economic['고용률(%)'] = economic['취업자 (천명)'] / economic['15세이상인구 (천명)'] *100
economic.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 34 entries, 0 to 33
# Data columns (total 10 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   행정구역(시도)      34 non-null     object
#  1   성별            34 non-null     object
#  2   15세이상인구 (천명)  34 non-null     int64
#  3   경제활동인구 (천명)   34 non-null     int64
#  4   취업자 (천명)      34 non-null     int64
#  5   실업자 (천명)      34 non-null     int64
#  6   비경제활동인구 (천명)  34 non-null     int64
#  7   경제활동참가율(％)    34 non-null     float64
#  8   고용률(%)        34 non-null     float64
#  9   실업률(%)        28 non-null     float64
# dtypes: float64(3), int64(5), object(2)
# memory usage: 2.8+ KB

# %%
state_emp = economic[['행정구역(시도)','고용률(%)']].groupby('행정구역(시도)',as_index = False).mean()

state_emp.head()
# Out:
#   행정구역(시도)     고용률(%)
# 0      강원도  63.980543
# 1      경기도  64.251431
# 2     경상남도  61.391891
# 3     경상북도  64.097240
# 4    광주광역시  59.787050

# %%
# 5) 시도별 고용률 평균 막대 그래프로 시각화하고 고용률이 가장 높은 지역 확인
# Vertical Bar (수직 막대그래프)
plt.figure(figsize =(8,4))
plt.bar(state_emp['행정구역(시도)'],state_emp['고용률(%)'])
plt.xticks(rotation = 45)
plt.title('시도별 고용률 평균 시각화')
plt.xlabel('행정구역(시도)')
plt.ylabel('고용률(%)', rotation = 0)
# ylim 크기 55~80 조절해서 확인
plt.ylim(55,80)
plt.show()

# %% [markdown]
# ### 종합 실습
# - 전국 교통사고 2017년 데이터를 이용해서 시각화 작업을 해보자

# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt

# %%
# 데이터 불러오기
data = pd.read_csv('./data/Traffic_Accident_2017.csv', encoding = 'euc-kr')
data.head()
# Out:
#     발생년      발생년월일시  발생분  주야 요일  사망자수  사상자수  중상자수  경상자수  부상신고자수  ... 도로형태_대분류  \
# 0  2017  2017010101   15  야간  일     1     2     1     0       0  ...      단일로
# 1  2017  2017010102   28  야간  일     1     1     0     0       0  ...      교차로
# 2  2017  2017010102   43  야간  일     1     2     0     1       0  ...      단일로
# 3  2017  2017010102   22  야간  일     1     1     0     0       0  ...      단일로
# 4  2017  2017010104   37  야간  일     1     1     0     0       0  ...      단일로
#
#     도로형태 당사자종별_1당_대분류 당사자종별_1당 당사자종별_2당_대분류 당사자종별_2당 발생위치X_UTMK 발생위치Y_UTMK  \
# 0  기타단일로          승용차      승용차          승용차      승용차     933501    1700129
# 1  교차로부근          승용차      승용차          보행자      보행자     967570    1944453
# 2  기타단일로          승용차      승용차          승용차      승용차     916497    1842880
# 3  기타단일로          승용차      승용차           없음       없음     961608    1864573
# 4  기타단일로          승용차      승용차          보행자      보행자     946778    1941695
#
#            경도         위도
# ...

# %%
data.columns
# Out:
# Index(['발생년', '발생년월일시', '발생분', '주야', '요일', '사망자수', '사상자수', '중상자수', '경상자수',
#        '부상신고자수', '발생지시도', '발생지시군구', '사고유형_대분류', '사고유형_중분류', '사고유형', '법규위반_대분류',
#        '법규위반', '도로형태_대분류', '도로형태', '당사자종별_1당_대분류', '당사자종별_1당', '당사자종별_2당_대분류',
#        '당사자종별_2당', '발생위치X_UTMK', '발생위치Y_UTMK', '경도', '위도'],
#       dtype='object')

# %%
# 1. 요일별 사고 건수 count
temp = data['요일'].value_counts()
y = temp[['월','화','수','목','금','토','일']]
y
# Out:
# 요일
# 월    603
# 화    608
# 수    565
# 목    586
# 금    603
# 토    596
# 일    504
# Name: count, dtype: int64

# %%
# 1-1 한글 보이게 만들어주기
#한글 폰트 깨질 경우
plt.rcParams['font.family'] = 'Malgun Gothic'

# %%
# 2. bar차트 그려보기
x = y.index
plt.bar(x,y)
plt.show()

# %%
# 3. 그래프 설명 추가하기(라벨 붙이기)
plt.bar(x,y)
plt.title("요일별 사고 건수")
plt.xlabel("요일")
plt.ylabel("사고 건수", rotation = 0)

plt.show()

# %%
# 4. y축 범위 설정하기
plt.bar(x,y)
plt.title("요일별 사고 건수")
plt.xlabel("요일")
plt.ylabel("사고 건수", rotation = 45)
plt.ylim(500,620)
plt.show()

# %%
plt.barh(y,x)
plt.title("요일별 사고 건수")
plt.xlabel("요일")
plt.ylabel("사고 건수", rotation = 45)
plt.ylim(500,620)
plt.show()

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4065 entries, 0 to 4064
# Data columns (total 27 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   발생년           4065 non-null   int64
#  1   발생년월일시        4065 non-null   int64
#  2   발생분           4065 non-null   int64
#  3   주야            4065 non-null   object
#  4   요일            4065 non-null   object
#  5   사망자수          4065 non-null   int64
#  6   사상자수          4065 non-null   int64
#  7   중상자수          4065 non-null   int64
#  8   경상자수          4065 non-null   int64
#  9   부상신고자수        4065 non-null   int64
#  10  발생지시도         4065 non-null   object
#  11  발생지시군구        4065 non-null   object
#  12  사고유형_대분류      4065 non-null   object
#  13  사고유형_중분류      4065 non-null   object
#  14  사고유형          4065 non-null   object
#  15  법규위반_대분류      4065 non-null   object
#  16  법규위반          4065 non-null   object
#  17  도로형태_대분류      4065 non-null   object
# ...

# %% [markdown]
# ### 종합 연습문제2
# - 차대차 사건 중 죽거나 다친 사람이 많은 발생지 시도별 시각화를 진행하자

# %%
data['사고유형_대분류'].unique()
# Out:
# array(['차대차', '차대사람', '차량단독', '철길건널목'], dtype=object)

# %%
# 차대차 서건만 뽑아오자 - 사고유형_대분류
ctc = data[data['사고유형_대분류'] == '차대차']
ctc
# Out:
#        발생년      발생년월일시  발생분  주야 요일  사망자수  사상자수  중상자수  경상자수  부상신고자수  ...  \
# 0     2017  2017010101   15  야간  일     1     2     1     0       0  ...
# 2     2017  2017010102   43  야간  일     1     2     0     1       0  ...
# 8     2017  2017010118   33  야간  일     1     3     1     1       0  ...
# 9     2017  2017010120    0  야간  일     1     7     4     2       0  ...
# 17    2017  2017010209    0  주간  월     1     2     1     0       0  ...
# ...    ...         ...  ...  .. ..   ...   ...   ...   ...     ...  ...
# 4050  2017  2017123009   58  주간  토     1     1     0     0       0  ...
# 4055  2017  2017123023   50  야간  토     1     6     2     3       0  ...
# 4058  2017  2017123112   10  주간  일     1     1     0     0       0  ...
# 4060  2017  2017123118   10  야간  일     1     4     1     0       2  ...
# 4063  2017  2017123120   40  야간  일     1    11     1     9       0  ...
#
#      도로형태_대분류   도로형태 당사자종별_1당_대분류 당사자종별_1당 당사자종별_2당_대분류 당사자종별_2당 발생위치X_UTMK  \
# ...

# %%
ctc['사고유형_대분류'].value_counts()
# Out:
# 사고유형_대분류
# 차대차    1642
# Name: count, dtype: int64

# %%
# 해당하는 데이터를 발생지 시도별로 합계를 구해보자
ctcp = ctc[['발생지시도','사상자수']].groupby('발생지시도').sum()
ctcp
# Out:
#        사상자수
# 발생지시도
# 강원      214
# 경기      824
# 경남      248
# 경북      287
# 광주       87
# 대구      115
# 대전       61
# 부산      107
# 서울      197
# 세종       17
# 울산       73
# 인천       66
# 전남      298
# 전북      244
# 제주       50
# 충남      351
# 충북      261

# %%
# 그래프의 x축, y축
x = ctcp.index
y = ctcp.values

# %%
# 데이터를 입력해서 그래프를 그려주자
plt.figure(figsize=(15,8))
plt.plot(x,y)
plt.xlabel("지역")
plt.ylabel("사상자수", rotation = 0)
plt.title("차대차 교통사고 사상자 수")
plt.show()

# %%
# bar그래프를 그리기 위해서는 2차원 데이터 -> 1차원 데이터로 바꿔줘야한다
y_bar = []
for i in range(len(y)):
    y_bar.append(y[i][0])

plt.figure(figsize=(15,8))
plt.bar(x,y_bar)
plt.xlabel("지역")
plt.ylabel("사상자수", rotation = 0)
plt.title("차대차 교통사고 사상자 수")
plt.show()

# %% [markdown]
# ### 종합 연습문제 3
# - 교통사고가 가장 많이 발생하는 시간대를 알아보고 파이차트를 이용해서 시각화 해보자

# %%
data.columns
# Out:
# Index(['발생년', '발생년월일시', '발생분', '주야', '요일', '사망자수', '사상자수', '중상자수', '경상자수',
#        '부상신고자수', '발생지시도', '발생지시군구', '사고유형_대분류', '사고유형_중분류', '사고유형', '법규위반_대분류',
#        '법규위반', '도로형태_대분류', '도로형태', '당사자종별_1당_대분류', '당사자종별_1당', '당사자종별_2당_대분류',
#        '당사자종별_2당', '발생위치X_UTMK', '발생위치Y_UTMK', '경도', '위도'],
#       dtype='object')

# %%
data['발생년월일시']
# Out:
# 0       2017010101
# 1       2017010102
# 2       2017010102
# 3       2017010102
# 4       2017010104
#            ...
# 4060    2017123118
# 4061    2017123118
# 4062    2017123119
# 4063    2017123120
# 4064    2017123123
# Name: 발생년월일시, Length: 4065, dtype: int64

# %%
# 발생년월일시에서 시간만 뽑아오자
time = data['발생년월일시'].astype('int64')
time %= 100
time
# Out:
# 0        1
# 1        2
# 2        2
# 3        2
# 4        4
#         ..
# 4060    18
# 4061    18
# 4062    19
# 4063    20
# 4064    23
# Name: 발생년월일시, Length: 4065, dtype: int64

# %%
# 시간을 카테고리화 시켜보자
bins = [-1,2,5,8,11,14,17,20,23]
label = ["0~2","3~5","6~8","9~11","12~14","15~17","18~20","21~23"]
rs = pd.cut(time, bins, labels =label)
rs
# Out:
# 0         0~2
# 1         0~2
# 2         0~2
# 3         0~2
# 4         3~5
#         ...
# 4060    18~20
# 4061    18~20
# 4062    18~20
# 4063    18~20
# 4064    21~23
# Name: 발생년월일시, Length: 4065, dtype: category
# Categories (8, object): ['0~2' < '3~5' < '6~8' < '9~11' < '12~14' < '15~17' < '18~20' < '21~23']

# %%
rs_data = rs.value_counts().sort_index()
rs_data
# Out:
# 발생년월일시
# 0~2      421
# 3~5      444
# 6~8      466
# 9~11     526
# 12~14    472
# 15~17    550
# 18~20    692
# 21~23    494
# Name: count, dtype: int64

# %%
# 그래프 그리기
plt.figure(figsize=(5,5))
plt.pie(rs_data, labels=label, autopct='%1.1f%%')
plt.title("시간대별 사고 발생 비율")
plt.show()
